# %% [markdown]
# # Simple Reactivity Inference

# %%
# %matplotlib inline

import sys
sys.path.insert(0, '..')

from src.util.plot import plot_reactivity
from src.models import k1_vigg

# Sequences to infer reactivities for
SEQUENCE = 'GGGGAAAACCCC'
# Call the infer method on a given model to predict reactivities
inference = k1_vigg.infer(SEQUENCE)

# Here we'll create a heatmap and display the raw data
display(plot_reactivity({'inference': inference}))
display(inference)
# Out:
#     id sequence_id  index_in_sequence  reactivity_DMS_MaP  reactivity_2A3_MaP
# 0    0          s0                  1            0.020020            0.116089
# 1    1          s0                  2            0.017746            0.089966
# 2    2          s0                  3            0.019638            0.075562
# 3    3          s0                  4            0.014702            0.131714
# 4    4          s0                  5            0.582031            0.349121
# 5    5          s0                  6            0.586914            0.376953
# 6    6          s0                  7            0.695801            0.430420
# 7    7          s0                  8            0.784668            0.445312
# 8    8          s0                  9            0.261475            0.066223
# 9    9          s0                 10            0.063843            0.009232
# 10  10          s0                 11            0.023300            0.008537
# ...
