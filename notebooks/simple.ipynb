# %% [markdown]
# # Simple Reactivity Inference

# %%
# %matplotlib inline

import sys
sys.path.insert(0, '..')

from src.util.plot import plot_reactivity
from src import models

# Sequences to infer reactivities for
SEQUENCE = 'GGGGAAAACCCC'
# Call the infer method on a given model to predict reactivities
inference = models.k1_vigg.infer(SEQUENCE)

# Here we'll create a heatmap and display the raw data
display(plot_reactivity(SEQUENCE, {'inference': inference}))
display(inference)
# Out:
#     id  reactivity_DMS_MaP  reactivity_2A3_MaP seq_id
# 0    0            0.020020            0.116089     s0
# 1    1            0.017746            0.089966     s0
# 2    2            0.019638            0.075562     s0
# 3    3            0.014702            0.131714     s0
# 4    4            0.582031            0.349121     s0
# 5    5            0.586914            0.376953     s0
# 6    6            0.695801            0.430420     s0
# 7    7            0.784668            0.445312     s0
# 8    8            0.261475            0.066223     s0
# 9    9            0.063843            0.009232     s0
# 10  10            0.023300            0.008537     s0
# 11  11            0.123596            0.025513     s0
